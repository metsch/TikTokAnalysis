# %%
import pandas as pd;
import json

filename = "biden_1817_1604410734"
df = pd.read_csv("../data/"+filename+".csv")
display(df.head())
display(df.columns)
# Out:
#    Unnamed: 0                                          itemInfos  \
# 0           0  {'id': '6839079433794505989', 'text': 'Reply t...
# 1           1  {'id': '6878420920826858757', 'text': 'if y’al...
# 2           2  {'id': '6870563083157327110', 'text': 'Orange ...
# 3           3  {'id': '6885800241275211014', 'text': 'We look...
# 4           4  {'id': '6889924077721521413', 'text': 'Oh my g...
#
#                                          authorInfos  \
# 0  {'secUid': 'MS4wLjABAAAAPrxASLep7yzGv3ZDK_w77u...
# 1  {'secUid': 'MS4wLjABAAAAf4gSyOyRiGF2wMAiss0Y9N...
# 2  {'secUid': 'MS4wLjABAAAA8ofqHKcjRpcUw3dX1290zd...
# 3  {'secUid': 'MS4wLjABAAAAfATU1xZSJWbMQZqBcUGiWg...
# 4  {'secUid': 'MS4wLjABAAAA7rv9YFzi6rIMUn57etk5tg...
#
#                                           musicInfos  \
# 0  {'musicId': '6839079417323571973', 'musicName'...
# 1  {'musicId': '6878420972907580165', 'musicName'...
# 2  {'musicId': '6859790371610691585', 'musicName'...
# 3  {'musicId': '6717515314562598913', 'musicName'...
# 4  {'musicId': '6835717014615640837', 'musicName'...
#
#                                    challengeInfoList  duetInfo  \
# 0  [{'challengeId': '1592744403631109', 'challeng...         0
# 1  [{'challengeId': '1592744403631109', 'challeng...         0
# 2  [{'challengeId': '1592744403631109', 'challeng...         0
# 3  [{'challengeId': '1592744403631109', 'challeng...         0
# 4  [{'challengeId': '1592744403631109', 'challeng...         0
#
#                                            textExtra  \
# 0  [{'AwemeId': '', 'Start': 9, 'End': 19, 'Hasht...
# 1  [{'AwemeId': '', 'Start': 61, 'End': 71, 'Hash...
# 2  [{'AwemeId': '', 'Start': 23, 'End': 29, 'Hash...
# 3  [{'AwemeId': '', 'Start': 45, 'End': 55, 'Hash...
# 4  [{'AwemeId': '', 'Start': 30, 'End': 40, 'Hash...
#
#                                          authorStats  \
# 0  {'followingCount': 263, 'followerCount': 19860...
# 1  {'followingCount': 205, 'followerCount': 17700...
# 2  {'followingCount': 26, 'followerCount': 223800...
# 3  {'followingCount': 1267, 'followerCount': 1900...
# 4  {'followingCount': 89, 'followerCount': 548600...
#
#                                      stickerTextList
# 0            [{'stickerType': 0, 'stickerText': []}]
# 1  [{'stickerType': 4, 'stickerText': ['i hope ya...
# 2                                                 []
# 3  [{'stickerType': 4, 'stickerText': ['All the w...
# 4                                                 []
# Index(['Unnamed: 0', 'itemInfos', 'authorInfos', 'musicInfos',
#        'challengeInfoList', 'duetInfo', 'textExtra', 'authorStats',
#        'stickerTextList'],
#       dtype='object')

# %%
n = len(df)
print(n)
error_count = 0
# Out:
# 1818

# %%
error_count = 0
def transform_row(row):   
    authorInfos_dict = row.authorInfos.replace("\'","\"")
    authorStats_dict = row.authorStats.replace("\'","\"")
    itemInfos_dict = row.itemInfos.replace("\'","\"")
    
    try:
        authorInfos = pd.DataFrame.from_dict(eval(authorInfos_dict),orient="index")
        authorStats = pd.DataFrame.from_dict(eval(authorStats_dict),orient="index")
        itemInfos = pd.DataFrame.from_dict(eval(itemInfos_dict),orient="index")
    except Exception:
        global error_count
        error_count = error_count + 1
        return
    
    
    authorInfos = authorInfos.transpose()
    authorInfos = authorInfos.filter(["userId","uniqueId","nickName","verified"],axis=1)
       
    authorStats = authorStats.transpose()
    authorStats = authorStats.filter(["followingCount","followerCount","heartCount","videoCount"],axis=1)
 
    itemInfos = itemInfos.transpose()
    itemInfos = itemInfos.filter(["id","authorId","shareCount","playCount","commentCount"],axis=1)


    textExtra = row.textExtra
    res = eval(textExtra)
    hashtags = set()
    
    for i in range(0,len(res)):
        if(res[i]["HashtagName"]):
            hashtags.add(res[i]["HashtagName"])
    
    row = pd.concat([
        itemInfos,
        authorStats,
        authorInfos
    ],axis=1)

    row["hashtags"] = None
    row.at[0,"hashtags"] = list(hashtags)
    row = row.rename(columns={"id":"itemId"})

    return row

# %%
# %%time
temp = transform_row(df.iloc[0])
data = pd.DataFrame(data=None,columns=temp.columns)

appended = []
for i in range(0,n-1):
    d = transform_row(df.iloc[i])
    appended.append(d)
    
data = pd.concat(appended)
print(len(data))
data = data.reset_index(drop=True)
# Out:
# 1762
# Wall time: 15.5 s

# %%
print("Unique Authors: ",len(data.authorId.unique()))
print("Unique Items: ",len(data.itemId.unique()))
#print("Unique Hashtags: ",len(data.hashtag.unique()))
print(data["verified"].value_counts())
# Out:
# Unique Authors:  1280
# Unique Items:  1762
# False    1715
# True       47
# Name: verified, dtype: int64

# %%
print(error_count)
print(n)
print(len(data.authorId.unique()))
data.head(5)
# Out:
# 55
# 1818
# 1280
#                 itemId             authorId shareCount playCount commentCount  \
# 0  6839079433794505989  6787000922671694853     344200  19400000       145900
# 1  6878420920826858757  6607210820815519746      44600  12800000        31100
# 2  6870563083157327110  6507754783003770882      56400  13600000        82600
# 3  6885800241275211014  6623394932903346181     135400  11100000        41800
# 4  6889924077721521413  6638646428809052166     154000  12300000        49900
#
#   followingCount followerCount heartCount videoCount               userId  \
# 0            263        198600    5900000         91  6787000922671694853
# 1            205        177000    5100000        154  6607210820815519746
# 2             26        223800    8000000        194  6507754783003770882
# 3           1267         19000    3100000         51  6623394932903346181
# 4             89        548600   20600000        128  6638646428809052166
#
#          uniqueId        nickName verified  \
# 0      nautical80           HD-80    False
# 1   name_brand_ag      AllieGrace    False
# 2    jayandsharon    Jay & Sharon    False
# 3  definitelynaht  Definitely not    False
# 4     meenaharris    Meena Harris     True
#
#                                             hashtags
# 0  [biden2020, trump2020, repost, parati, viral, ...
# 1  [biden2020, acab, leftist, feminist, blm, rbg,...
# 2  [biden2020, youhaveto, trump2020, foryou, come...
# 3  [worldseries, biden2020, vote, funny, gamingli...
# 4                                        [biden2020]

# %%
pr = data.explode("hashtags")
pr = pr.reset_index(drop=True)
pr

data.to_csv("../data/processed/"+filename+".csv")
pr.to_csv("../data/processed/"+filename+"_exploded.csv")
